# %% [markdown]
# ## Quick tests for

# %%
from sklearn.metrics import jaccard_similarity_score
import networkx as nx
import netrd as nd
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])

# %%
nx.draw(G, pos=nx.spring_layout(G),with_labels=True, font_weight='bold')

# %%
nx.draw(G, pos=nx.spring_layout(G),with_labels=True, font_weight='bold')

# %%
G2 = nx.Graph()
G2.add_nodes_from([1,2,3,4])
G2.add_edges_from([(1,2),(2,3),(3,4)])

# %%
nx.draw(G2, pos=nx.spring_layout(G),with_labels=True, font_weight='bold')

# %%
G3 = nx.Graph()
G3.add_nodes_from([1,2,3,4])

# %%
nx.draw(G3, pos=nx.spring_layout(G),with_labels=True, font_weight='bold')

# %%
G4 = nx.Graph()
G4.add_nodes_from([1,2,3])
G4.add_edges_from([(1,2),(2,3),(3,4)])

# %%
g1 = nx.to_numpy_matrix(G)
g2 = nx.to_numpy_matrix(G2)
g3 = nx.to_numpy_matrix(G3)
g4 = nx.to_numpy_matrix(G4)

# %%
jaccard_similarity_score(g1,g1)
# Out:
# 1.0

# %%
jaccard_similarity_score(g1,g2)
# Out:
# 0.75

# %%
jaccard_similarity_score(g1,g3)
# Out:
# 0.0

# %%
float(jaccard_similarity_score(g3,g3))
# Out:
# 1.0

# %%
float(jaccard_similarity_score(g1,g4))
# Out:
# 0.75
